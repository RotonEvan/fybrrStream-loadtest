# %%
import os
import json
from datetime import datetime 
import matplotlib.pylab as plt
from operator import add, truediv

# %%
import pandas as pd

# %%
def latency(uuid):
    start_time = 1611059608855
    with open(uuid) as f:
        node = json.load(f)
        for peer in node:
            arr = []
            fromNode = node[peer][0]['from'][:-37]
            toNode = node[peer][0]['to'][:-37]
            if node[peer][0]['to'] != peer:
                continue
            i = -1
            for obj in node[peer]:
                i = i + 1
                if i % 2 != 0:
                    continue
                if 'Video' in obj:
                    time = int((obj['Video']['timestamp']-1611071264507)/1000)
                    time = int(5 * round(time/5))
                    if time < 0:
                        continue
                    if time > 200:
                        break
                    arr.append({'Timestamp' : time, 'RTT' : obj['Video']['roundTripTime']})
            df = pd.DataFrame(arr)
            if 'Timestamp' not in df or df['Timestamp'][0] != 0:
                print(fromNode + '-' + toNode)
                continue
            df.to_csv('latency-csv/'+fromNode+'-'+toNode+'.csv')
#             print(df)

# %%
arr = os.listdir()
for filewa in arr:
    if filewa[-4:] != 'json':
        continue
    print("Node : ", filewa[5:-54], '\n')
    latency(filewa)
#     print()
# Out:
# Node :  Siddharth
#
# Node :  Moka
#
# Node :  Aditya
#
# Node :  Chinmay
#
# Node :  Sumit
#
# Node :  Yedla
#
# Node :  Vanisha
#
# Node :  Shivam
#
# Node :  Chaitnya
#
# Node :  Parth
#
# Node :  Arnav
#
# Node :  Satvik
#
# Node :  Amar
#
# Node :  Anees
#
# Node :  Niket
#
# Node :  Rishitha
#
# Node :  Nidhi
#
# Node :  Sankalp
#
# Node :  Prakhar
#
# Node :  Prabhadh
#
# Node :  Ruchika
#
# Node :  Raghvendra
#
# Node :  Prthamesh
#
# Node :  Vijay
#
# Node :  NIshant
#
# Node :  Sharisth
#
# Node :  Himanshu
#
# Node :  Tishang
#
# Node :  Anshu
#
# Node :  Prashant
#
# Node :  Shubham
#
# Node :  Mohit
#
# Node :  Shwetha
#
# Node :  Vaishnavi
#
# Node :  Ashmesh
#
# Node :  Sarthak
#
# Node :  ChinmaySahoo
#
# Node :  Jysamrani
#
# Node :  Basant
#
# Node :  Vidhi
#
# Node :  Ayush
#
# Node :  Shashwat
#
# Node :  Pravin
#
# Node :  Srindhi
#
# Node :  Jaysoni
#
# Node :  Shivank
#
# Node :  Mansi
#
# Node :  Lohit
#
# Node :  Arshpreet
#
# Arshpreet-Aditi
# Node :  Yash
#
# Node :  Avatansh
#
# Node :  Shreyas
#
# Node :  Ansh
#
# Node :  Harshit
#
# Harshit-Siddharth
# Node :  Unique
#
# Node :  Aditi

# %%
csv_files = os.listdir('latency-csv/')
for file in csv_files:
    if file[-3:] != 'csv':
        continue
    print(file[:-4])
    df = pd.read_csv("latency-csv/"+file)
    if 'Timestamp' not in df:
        print('Dataframe erroneous')
        continue
    time = df['Timestamp']
    rtt = df['RTT']
    plt.plot(time,rtt)
    plt.xlabel('Time')
    plt.ylabel('RTT')
    plt.show()

# %%
def isPresent(file, node):

# %%
def recurse(node, rtt=[0]*41):
#     print(node)
    csv_files = os.listdir('latency-csv/')
    for file in csv_files:
        if file.find(node) == 0:
            df = pd.read_csv('latency-csv/'+file)
#             if ts > len(df['RTT']):
#                 continue
            df['New-RTT'] = df['RTT'] + rtt
            df['Old-RTT'] = rtt
            df.to_csv('latency-csv/'+file)
            recurse(file[file.find('-')+1:-4], df['New-RTT'])

# %%
csv_files = os.listdir('latency-csv/')
for file in csv_files:
    df = pd.read_csv('latency-csv/'+file)
    if 'RTT' not in df:
        continue
    if len(df['RTT']) > 41:
        df.drop(df.tail(1).index,inplace=True)
        df.to_csv('latency-csv/'+file)
#     print(file)
#     print(len(df['RTT']))
# Out:
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41

# %%
root1 = 'Prabadh'
root2 = 'Parth'
# print(root2)
recurse(root1)
recurse(root2)

# %%
csv_files = os.listdir('latency-csv/')
for file in csv_files:
    df = pd.read_csv('latency-csv/'+file)
    print(file)
    print(df.head(5))
# Out:
# Srindhi-Nishant.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.002    0.001
# 1           1             1  0.001          5    0.002    0.001
# 2           2             2  0.016          5    0.017    0.001
# 3           3             3  0.001         10    0.002    0.001
# 4           4             4  0.002         20    0.003    0.001
# Raghavendra-Ruchika.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp
# 0           0             0  0.001          0
# 1           1             1  0.001          0
# 2           2             2  0.002         10
# 3           3             3  0.002         15
# 4           4             4  0.001         20
# Yedla-Jaysoni.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.002          0
# 1           1  0.014          5
# 2           2  0.002         10
# 3           3  0.002         15
# 4           4  0.001         20
# Siddharth-Sumit.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.001        0
# 1           1             1  0.001          5    0.001        0
# 2           2             2  0.001         10    0.001        0
# 3           3             3  0.001         15    0.001        0
# 4           4             4  0.001         20    0.001        0
# Vijay-Harshit.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.003          0
# 1           1  0.001          5
# 2           2  0.001         10
# 3           3  0.002         15
# 4           4  0.001         20
# Unique-Himanshu.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.002          0
# 1           1  0.002          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.010         20
# Chinmay-Vijay.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.008          0
# 1           1  0.001          5
# 2           2  0.007         10
# 3           3  0.001         15
# 4           4  0.010         20
# Chaitnya-Prathamesh.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.014          0
# 1           1  0.001          5
# 2           2  0.002         10
# 3           3  0.001         15
# 4           4  0.001         20
# Shivank-Niket.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.001          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.007         20
# Siddharth-Arshpreet.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.037          0    0.037        0
# 1           1             1  0.001          5    0.001        0
# 2           2             2  0.001         10    0.001        0
# 3           3             3  0.001         15    0.001        0
# 4           4             4  0.001         20    0.001        0
# .~lock.Vijay-Lohit.csv#
# Empty DataFrame
# Columns: [Unnamed: 0, roton, roton-ideapad, 07.02.2021 01:34, file:///home/roton/.config/libreoffice/4;]
# Index: []
# Yedla-Anshu.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.002          0
# 1           1  0.001          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.001         20
# Avatansh-Vanisha.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.002    0.001
# 1           1             1  0.001          5    0.002    0.001
# 2           2             2  0.001         10    0.002    0.001
# 3           3             3  0.001         15    0.002    0.001
# 4           4             4  0.001         15    0.002    0.001
# Avatansh-Aditya.csv
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    RTT  Timestamp  New-RTT  \
# 0           0             0               0  0.014          0    0.015
# 1           1             1               1  0.002          0    0.003
# 2           2             2               2  0.001          5    0.002
# 3           3             3               3  0.001         15    0.002
# 4           4             4               4  0.001         15    0.002
#
#    Old-RTT
# 0    0.001
# 1    0.001
# 2    0.001
# 3    0.001
# 4    0.001
# Raghavendra-Satvik.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.002          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.002         20
# Siddharth-Avatansh.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.001        0
# 1           1             1  0.001          5    0.001        0
# 2           2             2  0.001         10    0.001        0
# 3           3             3  0.001         15    0.001        0
# 4           4             4  0.001         20    0.001        0
# Chinmay-Chaitnya.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.001          5
# 2           2  0.050         10
# 3           3  0.003         15
# 4           4  0.009         20
# Chaitnya-Raghavendra.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.005          0
# 1           1  0.001          5
# 2           2  0.012         10
# 3           3  0.001         15
# 4           4  0.012         20
# Arshpreet-Shashwat.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.038    0.037
# 1           1             1  0.001          0    0.002    0.001
# 2           2             2  0.036         10    0.037    0.001
# 3           3             3  0.001         15    0.002    0.001
# 4           4             4  0.001         20    0.002    0.001
# Shivank-Moka.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.002          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.001         20
# Arshpreet-ChinmaySahoo.csv
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    RTT  Timestamp  New-RTT  \
# 0           0             0               0  0.001          0    0.038
# 1           1             1               1  0.001          5    0.002
# 2           2             2               2  0.001         10    0.002
# 3           3             3               3  0.001         15    0.002
# 4           4             4               4  0.001         20    0.002
#
#    Old-RTT
# 0    0.037
# 1    0.001
# 2    0.001
# 3    0.001
# 4    0.001
# Avatansh-Ashmesh.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.004          0    0.005    0.001
# 1           1             1  0.001          0    0.002    0.001
# 2           2             2  0.001         10    0.002    0.001
# 3           3             3  0.001         10    0.002    0.001
# 4           4             4  0.001         15    0.002    0.001
# Vijay-Shubham.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.012          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.002         20
# Shivank-Aneesh.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.001          5
# 2           2  0.026         10
# 3           3  0.001         15
# 4           4  0.002         20
# Mansi-Nidhi.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.002    0.001
# 1           1             1  0.001          0    0.002    0.001
# 2           2             2  0.001          5    0.002    0.001
# 3           3             3  0.001         10    0.013    0.012
# 4           4             4  0.001         15    0.002    0.001
# Shreyas-Vidhi.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.001          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.001         20
# Arshpreet-Sankalp.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.002          0    0.039    0.037
# 1           1             1  0.001          0    0.002    0.001
# 2           2             2  0.001         10    0.002    0.001
# 3           3             3  0.001         15    0.002    0.001
# 4           4             4  0.001         15    0.002    0.001
# Unique-Sharisth.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.002          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.001         20
# Chaitnya-Shreyas.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.001          5
# 2           2  0.001         10
# 3           3  0.003         15
# 4           4  0.001         20
# Raghavendra-Aditi.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.022          0
# 1           1  0.001          5
# 2           2  0.001          5
# 3           3  0.001         15
# 4           4  0.001         20
# Chinmay-Shivank.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.026          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.001         20
# Srindhi-Prabhadh.csv
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    RTT  Timestamp  New-RTT  \
# 0           0             0               0  0.002          0    0.003
# 1           1             1               1  0.001          0    0.002
# 2           2             2               2  0.001         10    0.002
# 3           3             3               3  0.001         10    0.002
# 4           4             4               4  0.021         15    0.022
#
#    Old-RTT
# 0    0.001
# 1    0.001
# 2    0.001
# 3    0.001
# 4    0.001
# Yedla-Basant.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.002          0
# 1           1  0.001          5
# 2           2  0.001         10
# 3           3  0.002         15
# 4           4  0.001         20
# Siddharth-Mansi.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.001        0
# 1           1             1  0.001          5    0.001        0
# 2           2             2  0.001         10    0.001        0
# 3           3             3  0.012         15    0.012        0
# 4           4             4  0.001         20    0.001        0
# Shivank-Shwetha.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.006          0
# 1           1  0.004          5
# 2           2  0.002         10
# 3           3  0.008         15
# 4           4  0.001         20
# Unique-Arnav.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.002          0
# 1           1  0.001          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.001         20
# Shreyas-Mohit.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.006          5
# 2           2  0.002         10
# 3           3  0.001         15
# 4           4  0.001         20
# Srindhi-Jysamrani.csv
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    RTT  Timestamp  New-RTT  \
# 0           0             0               0  0.001          0    0.002
# 1           1             1               1  0.001          5    0.002
# 2           2             2               2  0.002          5    0.003
# 3           3             3               3  0.002         10    0.003
# 4           4             4               4  0.001         20    0.002
#
#    Old-RTT
# 0    0.001
# 1    0.001
# 2    0.001
# 3    0.001
# 4    0.001
# Vijay-Ansh.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.002          5
# 2           2  0.002         10
# 3           3  0.001         15
# 4           4  0.002         20
# Shreyas-Pravin.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.001          5
# 2           2  0.002         10
# 3           3  0.001         15
# 4           4  0.001         20
# Shreyas-Yash.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.002          0
# 1           1  0.016          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.001         20
# Avatansh-Srindhi.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.002    0.001
# 1           1             1  0.001          5    0.002    0.001
# 2           2             2  0.001          5    0.002    0.001
# 3           3             3  0.001         10    0.002    0.001
# 4           4             4  0.001         15    0.002    0.001
# Vijay-Lohit.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.001          5
# 2           2  0.003         10
# 3           3  0.001         15
# 4           4  0.001         20
# Mansi-Prakhar.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.002          0    0.003    0.001
# 1           1             1  0.001          0    0.002    0.001
# 2           2             2  0.001          5    0.002    0.001
# 3           3             3  0.040         10    0.052    0.012
# 4           4             4  0.002         15    0.003    0.001
# Arshpreet-Ayush.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.038    0.037
# 1           1             1  0.001          0    0.002    0.001
# 2           2             2  0.020         10    0.021    0.001
# 3           3             3  0.001         15    0.002    0.001
# 4           4             4  0.001         20    0.002    0.001
# Raghavendra-Vaishnavi.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.002          0
# 1           1  0.002          5
# 2           2  0.001         10
# 3           3  0.002         10
# 4           4  0.002         20
# Chinmay-Unique.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.002          0
# 1           1  0.001          5
# 2           2  0.032         10
# 3           3  0.001         15
# 4           4  0.001         20
# Yedla-Sarthak.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.019          5
# 2           2  0.004         10
# 3           3  0.001         15
# 4           4  0.001         20
# Unique-Tishang.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.001          5
# 2           2  0.033         10
# 3           3  0.001         15
# 4           4  0.002         20
# Srindhi-Parth.csv
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    RTT  Timestamp  New-RTT  \
# 0           0             0               0  0.001          0    0.002
# 1           1             1               1  0.011          0    0.012
# 2           2             2               2  0.001         10    0.002
# 3           3             3               3  0.019         15    0.020
# 4           4             4               4  0.005         15    0.006
#
#    Old-RTT
# 0    0.001
# 1    0.001
# 2    0.001
# 3    0.001
# 4    0.001
# Chaitnya-Yedla.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.008          0
# 1           1  0.012          5
# 2           2  0.001         10
# 3           3  0.002         15
# 4           4  0.001         20

# %%
df = pd.read_csv('latency-csv/Parth-Sumit.csv')
print(df.head())
df = pd.read_csv('latency-csv/Sumit-Unique.csv')
print(df.head())
df = pd.read_csv('latency-csv/Unique-Anees.csv')
print(df.head())
df = pd.read_csv('latency-csv/Anees-Vaishnavi.csv')
print(df.head())
# Out:
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.003          0    0.003        0
# 1           1             1  0.001          5    0.001        0
# 2           2             2  0.002         10    0.002        0
# 3           3             3  0.005         15    0.005        0
# 4           4             4  0.005         20    0.005        0
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    RTT  Timestamp  New-RTT  \
# 0           0             0               0  0.006          0    0.009
# 1           1             1               1  0.019          0    0.020
# 2           2             2               2  0.004          5    0.006
# 3           3             3               3  0.002         10    0.007
# 4           4             4               4  0.001         15    0.006
#
#    Old-RTT
# 0    0.003
# 1    0.001
# 2    0.002
# 3    0.005
# 4    0.005
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    RTT  Timestamp  New-RTT  \
# 0           0             0               0  0.003          0    0.012
# 1           1             1               1  0.004          5    0.024
# 2           2             2               2  0.005          5    0.011
# 3           3             3               3  0.003         15    0.010
# 4           4             4               4  0.001         20    0.007
#
#    Old-RTT
# 0    0.009
# 1    0.020
# 2    0.006
# 3    0.007
# 4    0.006
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.013    0.012
# 1           1             1  0.001          5    0.025    0.024
# 2           2             2  0.001         10    0.012    0.011
# 3           3             3  0.012         10    0.022    0.010
# 4           4             4  0.001         20    0.008    0.007

# %%
def findLeaf(node):
    flag = False
    csv_files = os.listdir('latency-csv/')
    for file in csv_files:
        if file.find(node) == 0:
            flag = True
            findLeaf(file[file.find('-')+1:-4])
    if flag == False:
        leaf_arr.append(node)

# %%
leaf_arr = []
findLeaf('Prabadh')
findLeaf('Parth')
leaf_arr
# Out:
# ['Prabadh',
#  'Prakhar',
#  'Satvik',
#  'Vanisha',
#  'Vaishnavi',
#  'Vidhi',
#  'Sarthak',
#  'Shubham',
#  'Yash',
#  'Tishang',
#  'Shwetha',
#  'Pravin',
#  'Basant',
#  'Sharisth',
#  'Niket',
#  'Nidhi',
#  'Amar',
#  'Jaysoni',
#  'Siddharth',
#  'Lohit',
#  'Pravin',
#  'Basant',
#  'Sharisth',
#  'Niket',
#  'Nidhi',
#  'Amar',
#  'Jaysoni',
#  'Siddharth',
#  'Mohit',
#  'NIshant',
#  'Prashant']

# %%
df1 = pd.DataFrame()
df1['Latency'] = [0] * 41
df1['Time'] = [0] * 41
csv_files = os.listdir('latency-csv/')
for file in csv_files:
    if file[file.find('-')+1:-4] in leaf_arr:
        df = pd.read_csv('latency-csv/'+file)
        df1['Latency'] = (df1['Latency'] + df['New-RTT'])/2
        df1['Time'] = df['Timestamp']
df1.to_csv('latency-csv/latency.csv')

# %%
df = pd.read_csv('latency-csv/latency.csv')
print(df)
time = df['Time']
latency = df['Latency']
plt.plot(time, latency)
plt.xlabel('Time (s)')
plt.ylabel('Latency (s)')
plt.savefig('latency.png')
plt.savefig('latency.pdf')
plt.show()
# Out:
#     Unnamed: 0   Latency  Time
# 0            0  0.018507     0
# 1            1  0.041216     0
# 2            2  0.028129     5
# 3            3  0.015606    10
# 4            4  0.020933    15
# 5            5  0.034012    20
# 6            6  0.018065    25
# 7            7  0.040499    30
# 8            8  0.036627    35
# 9            9  0.023247    40
# 10          10  0.032457    45
# 11          11  0.021508    50
# 12          12  0.019560    55
# 13          13  0.010720    60
# 14          14  0.025670    65
# 15          15  0.041961    70
# 16          16  0.006281    75
# 17          17  0.008069    80
# 18          18  0.009915    85
# 19          19  0.008441    90
# 20          20  0.005510    95
# 21          21  0.007241   100
# 22          22  0.033215   105
# 23          23  0.006170   110
# 24          24  0.007090   115
# 25          25  0.006424   120
# 26          26  0.016135   125
# 27          27  0.009208   130
# 28          28  0.008292   135
# 29          29  0.015849   140
# 30          30  0.012892   145
# 31          31  0.013510   150
# 32          32  0.005874   155
# 33          33  0.039794   160
# 34          34  0.016343   165
# 35          35  0.008541   170
# 36          36  0.007828   175
# 37          37  0.007020   180
# 38          38  0.036603   185
# 39          39  0.020746   190
# 40          40  0.007184   195

# %%
df_normal = pd.read_csv('latency-csv/latency_normal.csv')
df_binary = pd.read_csv('latency-csv/latency.csv')
print(df_Normal.head())
print(df_Binary.head())
# Out:
#    Unnamed: 0   Latency  Time
# 0           0  0.005339     0
# 1           1  0.011444     0
# 2           2  0.029665    10
# 3           3  0.013063    15
# 4           4  0.007339    15
#    Unnamed: 0   Latency  Time
# 0           0  0.018507     0
# 1           1  0.041216     0
# 2           2  0.028129     5
# 3           3  0.015606    10
# 4           4  0.020933    15

# %%
lat1 = df_normal['Latency'][:41]
t1 = df_normal['Time'][:41]
lat2 = df_binary['Latency']
t2 = df_binary['Time']
plt.plot(t1, lat1, label='fybrrStream')
plt.plot(t2, lat2, label='binary tree')
plt.xlabel('Time (s)')
plt.ylabel('Latency (s)')
plt.legend()
plt.savefig('multi-line.png')
plt.savefig('multi-line.pdf')
plt.show()
