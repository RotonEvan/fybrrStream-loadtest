# %%
import os
import json
from datetime import datetime 
import matplotlib.pylab as plt
from operator import add, truediv

# %%
import pandas as pd

# %%
def latency(uuid):
    start_time = 1611059608855
    with open(uuid) as f:
        node = json.load(f)
        for peer in node:
            arr = []
            fromNode = node[peer][0]['from'][:-37]
            toNode = node[peer][0]['to'][:-37]
            if node[peer][0]['to'] != peer:
                continue
            i = -1
            for obj in node[peer]:
                i = i + 1
                if i % 2 != 0:
                    continue
                if 'Video' in obj:
                    time = int((obj['Video']['timestamp']-1611071264507)/1000)
                    time = int(5 * round(time/5))
                    if time < 0:
                        continue
                    if time > 1100:
                        break
                    arr.append({'Timestamp' : time, 'RTT' : obj['Video']['roundTripTime']})
            df = pd.DataFrame(arr)
            if 'Timestamp' not in df or df['Timestamp'][0] != 0:
                print(fromNode + '-' + toNode)
                continue
            df.to_csv('latency-csv/'+fromNode+'-'+toNode+'.csv')
#             print(df)

# %%
arr = os.listdir()
for filewa in arr:
    if filewa[-4:] != 'json':
        continue
    print("Node : ", filewa[5:-54], '\n')
    latency(filewa)
#     print()
# Out:
# Node :  Siddharth
#
# Node :  Moka
#
# Node :  Aditya
#
# Node :  Chinmay
#
# Node :  Sumit
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-7aa12b3a671f> in <module>
#       4         continue
#       5     print("Node : ", filewa[5:-54], '\n')
# ----> 6     latency(filewa)
#       7 #     print()
#
# <ipython-input-3-3348e8fbf3f3> in latency(uuid)
#      26                 print(fromNode + '-' + toNode)
#      27                 continue
# ---> 28             df.to_csv('latency-csv/'+fromNode+'-'+toNode+'.csv')
#      29 #             print(df)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/formats/csvs.py in save(self)
#     155             f, handles = _get_handle(self.path_or_buf, self.mode,
#     156                                      encoding=self.encoding,
# --> 157                                      compression=self.compression)
#     158             close = True
#     159
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     422         elif encoding:
#     423             # Python 3 and encoding
# --> 424             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     425         elif is_text:
#     426             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latency-csv/Sumit-Unique.csv'

# %%
csv_files = os.listdir('latency-csv/')
for file in csv_files:
    if file[-3:] != 'csv':
        continue
    print(file[:-4])
    df = pd.read_csv("latency-csv/"+file)
    if 'Timestamp' not in df:
        print('Dataframe erroneous')
        continue
    time = df['Timestamp']
    rtt = df['RTT']
    plt.plot(time,rtt)
    plt.xlabel('Time')
    plt.ylabel('RTT')
    plt.show()

# %%
def isPresent(file, node):

# %%
def recurse(node, rtt=[0]*221):
#     print(node)
    csv_files = os.listdir('latency-csv/')
    for file in csv_files:
        if file.find(node) == 0:
            df = pd.read_csv('latency-csv/'+file)
#             if ts > len(df['RTT']):
#                 continue
            df['New-RTT'] = df['RTT'] + rtt
            df['Old-RTT'] = rtt
            df.to_csv('latency-csv/'+file)
            recurse(file[file.find('-')+1:-4], df['New-RTT'])

# %%
csv_files = os.listdir('latency-csv/')
for file in csv_files:
    df = pd.read_csv('latency-csv/'+file)
    if 'RTT' not in df:
        continue
    if len(df['RTT']) > 221:
        df.drop(df.tail(1).index,inplace=True)
        df.to_csv('latency-csv/'+file)
#     print(file)
#     print(len(df['RTT']))

# %%
root1 = 'Siddharth'
root2 = 'Chinmay'
# print(root2)
recurse(root1)
recurse(root2)

# %%
csv_files = os.listdir('latency-csv/')
for file in csv_files:
    df = pd.read_csv('latency-csv/'+file)
    print(file)
    print(df.head(5))
# Out:
# Srindhi-Nishant.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.002    0.001
# 1           1             1  0.001          5    0.002    0.001
# 2           2             2  0.016          5    0.017    0.001
# 3           3             3  0.001         10    0.002    0.001
# 4           4             4  0.002         20    0.003    0.001
# Raghavendra-Ruchika.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp
# 0           0             0  0.001          0
# 1           1             1  0.001          0
# 2           2             2  0.002         10
# 3           3             3  0.002         15
# 4           4             4  0.001         20
# Yedla-Jaysoni.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.002          0
# 1           1  0.014          5
# 2           2  0.002         10
# 3           3  0.002         15
# 4           4  0.001         20
# Siddharth-Sumit.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.001        0
# 1           1             1  0.001          5    0.001        0
# 2           2             2  0.001         10    0.001        0
# 3           3             3  0.001         15    0.001        0
# 4           4             4  0.001         20    0.001        0
# Vijay-Harshit.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.003          0
# 1           1  0.001          5
# 2           2  0.001         10
# 3           3  0.002         15
# 4           4  0.001         20
# Unique-Himanshu.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.002          0
# 1           1  0.002          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.010         20
# Chinmay-Vijay.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.008          0
# 1           1  0.001          5
# 2           2  0.007         10
# 3           3  0.001         15
# 4           4  0.010         20
# Chaitnya-Prathamesh.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.014          0
# 1           1  0.001          5
# 2           2  0.002         10
# 3           3  0.001         15
# 4           4  0.001         20
# Shivank-Niket.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.001          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.007         20
# Siddharth-Arshpreet.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.037          0    0.037        0
# 1           1             1  0.001          5    0.001        0
# 2           2             2  0.001         10    0.001        0
# 3           3             3  0.001         15    0.001        0
# 4           4             4  0.001         20    0.001        0
# .~lock.Vijay-Lohit.csv#
# Empty DataFrame
# Columns: [Unnamed: 0, roton, roton-ideapad, 07.02.2021 01:34, file:///home/roton/.config/libreoffice/4;]
# Index: []
# Yedla-Anshu.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.002          0
# 1           1  0.001          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.001         20
# Avatansh-Vanisha.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.002    0.001
# 1           1             1  0.001          5    0.002    0.001
# 2           2             2  0.001         10    0.002    0.001
# 3           3             3  0.001         15    0.002    0.001
# 4           4             4  0.001         15    0.002    0.001
# Avatansh-Aditya.csv
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    RTT  Timestamp  New-RTT  \
# 0           0             0               0  0.014          0    0.015
# 1           1             1               1  0.002          0    0.003
# 2           2             2               2  0.001          5    0.002
# 3           3             3               3  0.001         15    0.002
# 4           4             4               4  0.001         15    0.002
#
#    Old-RTT
# 0    0.001
# 1    0.001
# 2    0.001
# 3    0.001
# 4    0.001
# Raghavendra-Satvik.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.002          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.002         20
# Siddharth-Avatansh.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.001        0
# 1           1             1  0.001          5    0.001        0
# 2           2             2  0.001         10    0.001        0
# 3           3             3  0.001         15    0.001        0
# 4           4             4  0.001         20    0.001        0
# Chinmay-Chaitnya.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.001          5
# 2           2  0.050         10
# 3           3  0.003         15
# 4           4  0.009         20
# Chaitnya-Raghavendra.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.005          0
# 1           1  0.001          5
# 2           2  0.012         10
# 3           3  0.001         15
# 4           4  0.012         20
# Arshpreet-Shashwat.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.038    0.037
# 1           1             1  0.001          0    0.002    0.001
# 2           2             2  0.036         10    0.037    0.001
# 3           3             3  0.001         15    0.002    0.001
# 4           4             4  0.001         20    0.002    0.001
# Shivank-Moka.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.002          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.001         20
# Arshpreet-ChinmaySahoo.csv
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    RTT  Timestamp  New-RTT  \
# 0           0             0               0  0.001          0    0.038
# 1           1             1               1  0.001          5    0.002
# 2           2             2               2  0.001         10    0.002
# 3           3             3               3  0.001         15    0.002
# 4           4             4               4  0.001         20    0.002
#
#    Old-RTT
# 0    0.037
# 1    0.001
# 2    0.001
# 3    0.001
# 4    0.001
# Avatansh-Ashmesh.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.004          0    0.005    0.001
# 1           1             1  0.001          0    0.002    0.001
# 2           2             2  0.001         10    0.002    0.001
# 3           3             3  0.001         10    0.002    0.001
# 4           4             4  0.001         15    0.002    0.001
# Vijay-Shubham.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.012          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.002         20
# Shivank-Aneesh.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.001          5
# 2           2  0.026         10
# 3           3  0.001         15
# 4           4  0.002         20
# Mansi-Nidhi.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.002    0.001
# 1           1             1  0.001          0    0.002    0.001
# 2           2             2  0.001          5    0.002    0.001
# 3           3             3  0.001         10    0.013    0.012
# 4           4             4  0.001         15    0.002    0.001
# Shreyas-Vidhi.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.001          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.001         20
# Arshpreet-Sankalp.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.002          0    0.039    0.037
# 1           1             1  0.001          0    0.002    0.001
# 2           2             2  0.001         10    0.002    0.001
# 3           3             3  0.001         15    0.002    0.001
# 4           4             4  0.001         15    0.002    0.001
# Unique-Sharisth.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.002          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.001         20
# Chaitnya-Shreyas.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.001          5
# 2           2  0.001         10
# 3           3  0.003         15
# 4           4  0.001         20
# Raghavendra-Aditi.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.022          0
# 1           1  0.001          5
# 2           2  0.001          5
# 3           3  0.001         15
# 4           4  0.001         20
# Chinmay-Shivank.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.026          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.001         20
# Srindhi-Prabhadh.csv
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    RTT  Timestamp  New-RTT  \
# 0           0             0               0  0.002          0    0.003
# 1           1             1               1  0.001          0    0.002
# 2           2             2               2  0.001         10    0.002
# 3           3             3               3  0.001         10    0.002
# 4           4             4               4  0.021         15    0.022
#
#    Old-RTT
# 0    0.001
# 1    0.001
# 2    0.001
# 3    0.001
# 4    0.001
# Yedla-Basant.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.002          0
# 1           1  0.001          5
# 2           2  0.001         10
# 3           3  0.002         15
# 4           4  0.001         20
# Siddharth-Mansi.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.001        0
# 1           1             1  0.001          5    0.001        0
# 2           2             2  0.001         10    0.001        0
# 3           3             3  0.012         15    0.012        0
# 4           4             4  0.001         20    0.001        0
# Shivank-Shwetha.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.006          0
# 1           1  0.004          5
# 2           2  0.002         10
# 3           3  0.008         15
# 4           4  0.001         20
# Unique-Arnav.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.002          0
# 1           1  0.001          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.001         20
# Shreyas-Mohit.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.006          5
# 2           2  0.002         10
# 3           3  0.001         15
# 4           4  0.001         20
# Srindhi-Jysamrani.csv
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    RTT  Timestamp  New-RTT  \
# 0           0             0               0  0.001          0    0.002
# 1           1             1               1  0.001          5    0.002
# 2           2             2               2  0.002          5    0.003
# 3           3             3               3  0.002         10    0.003
# 4           4             4               4  0.001         20    0.002
#
#    Old-RTT
# 0    0.001
# 1    0.001
# 2    0.001
# 3    0.001
# 4    0.001
# Vijay-Ansh.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.002          5
# 2           2  0.002         10
# 3           3  0.001         15
# 4           4  0.002         20
# Shreyas-Pravin.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.001          5
# 2           2  0.002         10
# 3           3  0.001         15
# 4           4  0.001         20
# Shreyas-Yash.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.002          0
# 1           1  0.016          5
# 2           2  0.001         10
# 3           3  0.001         15
# 4           4  0.001         20
# Avatansh-Srindhi.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.002    0.001
# 1           1             1  0.001          5    0.002    0.001
# 2           2             2  0.001          5    0.002    0.001
# 3           3             3  0.001         10    0.002    0.001
# 4           4             4  0.001         15    0.002    0.001
# Vijay-Lohit.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.001          5
# 2           2  0.003         10
# 3           3  0.001         15
# 4           4  0.001         20
# Mansi-Prakhar.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.002          0    0.003    0.001
# 1           1             1  0.001          0    0.002    0.001
# 2           2             2  0.001          5    0.002    0.001
# 3           3             3  0.040         10    0.052    0.012
# 4           4             4  0.002         15    0.003    0.001
# Arshpreet-Ayush.csv
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.038    0.037
# 1           1             1  0.001          0    0.002    0.001
# 2           2             2  0.020         10    0.021    0.001
# 3           3             3  0.001         15    0.002    0.001
# 4           4             4  0.001         20    0.002    0.001
# Raghavendra-Vaishnavi.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.002          0
# 1           1  0.002          5
# 2           2  0.001         10
# 3           3  0.002         10
# 4           4  0.002         20
# Chinmay-Unique.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.002          0
# 1           1  0.001          5
# 2           2  0.032         10
# 3           3  0.001         15
# 4           4  0.001         20
# Yedla-Sarthak.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.019          5
# 2           2  0.004         10
# 3           3  0.001         15
# 4           4  0.001         20
# Unique-Tishang.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.001          0
# 1           1  0.001          5
# 2           2  0.033         10
# 3           3  0.001         15
# 4           4  0.002         20
# Srindhi-Parth.csv
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    RTT  Timestamp  New-RTT  \
# 0           0             0               0  0.001          0    0.002
# 1           1             1               1  0.011          0    0.012
# 2           2             2               2  0.001         10    0.002
# 3           3             3               3  0.019         15    0.020
# 4           4             4               4  0.005         15    0.006
#
#    Old-RTT
# 0    0.001
# 1    0.001
# 2    0.001
# 3    0.001
# 4    0.001
# Chaitnya-Yedla.csv
#    Unnamed: 0    RTT  Timestamp
# 0           0  0.008          0
# 1           1  0.012          5
# 2           2  0.001         10
# 3           3  0.002         15
# 4           4  0.001         20

# %%
df = pd.read_csv('latency-csv/Chinmay-Chaitnya.csv')
print(df.head())
df = pd.read_csv('latency-csv/Chaitnya-Raghavendra.csv')
print(df.head())
df = pd.read_csv('latency-csv/Raghavendra-Ruchika.csv')
print(df.head())
# Out:
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.001          0    0.001        0
# 1           1             1  0.001          5    0.001        0
# 2           2             2  0.050         10    0.050        0
# 3           3             3  0.003         15    0.003        0
# 4           4             4  0.009         20    0.009        0
#    Unnamed: 0  Unnamed: 0.1    RTT  Timestamp  New-RTT  Old-RTT
# 0           0             0  0.005          0    0.006    0.001
# 1           1             1  0.001          5    0.002    0.001
# 2           2             2  0.012         10    0.062    0.050
# 3           3             3  0.001         15    0.004    0.003
# 4           4             4  0.012         20    0.021    0.009
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    RTT  Timestamp  New-RTT  \
# 0           0             0               0  0.001          0    0.007
# 1           1             1               1  0.001          0    0.003
# 2           2             2               2  0.002         10    0.064
# 3           3             3               3  0.002         15    0.006
# 4           4             4               4  0.001         20    0.022
#
#    Old-RTT
# 0    0.006
# 1    0.002
# 2    0.062
# 3    0.004
# 4    0.021

# %%
def findLeaf(node):
    flag = False
    csv_files = os.listdir('latency-csv/')
    for file in csv_files:
        if file.find(node) == 0:
            flag = True
            findLeaf(file[file.find('-')+1:-4])
    if flag == False:
        leaf_arr.append(node)

# %%
leaf_arr = []
findLeaf('Siddharth')
findLeaf('Chinmay')
leaf_arr
# Out:
# ['Sumit',
#  'Shashwat',
#  'ChinmaySahoo',
#  'Sankalp',
#  'Ayush',
#  'Vanisha',
#  'Aditya',
#  'Ashmesh',
#  'Nishant',
#  'Prabhadh',
#  'Jysamrani',
#  'Parth',
#  'Nidhi',
#  'Prakhar',
#  'Harshit',
#  'Shubham',
#  'Ansh',
#  'Lohit',
#  'Prathamesh',
#  'Ruchika',
#  'Satvik',
#  'Aditi',
#  'Vaishnavi',
#  'Vidhi',
#  'Mohit',
#  'Pravin',
#  'Yash',
#  'Jaysoni',
#  'Anshu',
#  'Basant',
#  'Sarthak',
#  'Niket',
#  'Moka',
#  'Aneesh',
#  'Shwetha',
#  'Himanshu',
#  'Sharisth',
#  'Arnav',
#  'Tishang']

# %%
df1 = pd.DataFrame()
df1['Latency'] = [0] * 221
df1['Time'] = [0] * 221
csv_files = os.listdir('latency-csv/')
for file in csv_files:
    if file[file.find('-')+1:-4] in leaf_arr:
        df = pd.read_csv('latency-csv/'+file)
        df1['Latency'] = (df1['Latency'] + df['New-RTT'])/2
        df1['Time'] = df['Timestamp']
df1.to_csv('latency-csv/latency.csv')

# %%
df = pd.read_csv('latency-csv/latency.csv')
print(df)
time = df['Time']
latency = df['Latency']
plt.plot(time, latency)
plt.xlabel('Time (s)')
plt.ylabel('Latency (s)')
plt.savefig('latency.png')
plt.savefig('latency.pdf')
plt.show()
# Out:
#      Unnamed: 0   Latency  Time
# 0             0  0.005339     0
# 1             1  0.011444     0
# 2             2  0.029665    10
# 3             3  0.013063    15
# 4             4  0.007339    15
# 5             5  0.015349    25
# 6             6  0.025249    25
# 7             7  0.033581    30
# 8             8  0.014807    40
# 9             9  0.017461    40
# 10           10  0.014863    50
# 11           11  0.007446    55
# 12           12  0.053026    60
# 13           13  0.039661    65
# 14           14  0.043766    70
# 15           15  0.067526    75
# 16           16  0.033835    80
# 17           17  0.028988    85
# 18           18  0.056837    90
# 19           19  0.020923    95
# 20           20  0.027009    95
# 21           21  0.012829   100
# 22           22  0.018415   110
# 23           23  0.019805   110
# 24           24  0.031299   120
# 25           25  0.029307   120
# 26           26  0.036997   130
# 27           27  0.026432   135
# 28           28  0.037638   135
# 29           29  0.026015   140
# ..          ...       ...   ...
# 191         191  0.007403   955
# 192         192  0.002700   960
# 193         193  0.004800   965
# 194         194  0.003287   970
# 195         195  0.012906   975
# 196         196  0.023777   975
# 197         197  0.003603   980
# 198         198  0.016118   985
# 199         199  0.017900   995
# 200         200  0.005892   995
# 201         201  0.015383  1005
# 202         202  0.003279  1010
# 203         203  0.004833  1015
# 204         204  0.013520  1020
# 205         205  0.009450  1020
# 206         206  0.004929  1030
# 207         207  0.004332  1030
# 208         208  0.003697  1040
# 209         209  0.004491  1045
# 210         210  0.011490  1050
# 211         211  0.004410  1055
# 212         212  0.008606  1055
# 213         213  0.022148  1065
# 214         214  0.011031  1065
# 215         215  0.014010  1075
# 216         216  0.011838  1080
# 217         217  0.006200  1080
# 218         218  0.023962  1090
# 219         219  0.003931  1095
# 220         220  0.008009  1095
#
# [221 rows x 3 columns]
